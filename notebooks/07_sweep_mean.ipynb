# %% [markdown]
# # Sweep: MEAN Pooling
#
# Run this notebook in **Colab 2** while running `07_sweep_cls.ipynb` and `07_sweep_token.ipynb` in separate Colab runtimes.
#
# All results are saved to Google Drive so they can be merged later.

# %% [markdown]
# ## 1. Setup

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone or pull the repository
# !git clone https://github.com/TheMattWang/Negation-Origin-Tracing.git 2>/dev/null || (cd Negation-Origin-Tracing && git pull)
# %cd Negation-Origin-Tracing
# Out:
# /content/Negation-Origin-Tracing

# %%
# Install dependencies
# %pip install -q torch lightning transformers datasets pandas pyarrow matplotlib seaborn scikit-learn tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 23.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 64.9 MB/s eta 0:00:00

# %%
# Set shared output location on Google Drive
import os
os.environ['DRIVE_OUTPUT'] = '/content/drive/MyDrive/NOT_results'

# Create the directory
# !mkdir -p /content/drive/MyDrive/NOT_results

print(f"Results will be saved to: {os.environ['DRIVE_OUTPUT']}")
# Out:
# Results will be saved to: /content/drive/MyDrive/NOT_results

# %%
# Check GPU
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# GPU available: True
# GPU: Tesla T4

# %% [markdown]
# ## 2. Download Data

# %%
# Download data if needed
import os
if not os.path.exists('data/raw/train/sst.parquet'):
    print("Downloading data...")
    # !python src/data/download.py
else:
    print("Data already exists!")
# Out:
# Data already exists!

# %% [markdown]
# ## 3. Run MEAN Pooling Sweep
#
# This trains probes on all 6 layers using MEAN pooling.

# %%
# Run the MEAN sweep
# !chmod +x run_sweep_mean.sh
# !./run_sweep_mean.sh
# Out:
# Saving to Google Drive: /content/drive/MyDrive/NOT_results/sweep_mean
# ========================================
# Layer Sweep: MEAN Pooling
# ========================================
# Layers: 0-5
# Output: /content/drive/MyDrive/NOT_results/sweep_mean
#
#
# [Layer 0] MEAN pooling...
# 2025-12-02 21:36:30.173310: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764711390.192992     776 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764711390.198842     776 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764711390.213659     776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764711390.213677     776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764711390.213679     776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764711390.213681     776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 21:36:30.218361: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:11<00:00, 16.76it/s, train_loss_step=0.244, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:01<00:04,  9.69it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 12.17it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:02<00:01, 13.34it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:01, 14.01it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 14.44it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 14.69it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:14<00:00, 16.54it/s, train_loss_step=0.277, train_acc_step=0.800, val_loss=0.445, val_acc=0.794, val_auroc=0.858, train_loss_epoch=0.400, train_acc_epoch=0.822]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.98it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.73it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.65it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.59it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.54it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.67it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:15<00:00, 16.48it/s, train_loss_step=0.556, train_acc_step=0.800, val_loss=0.446, val_acc=0.784, val_auroc=0.864, train_loss_epoch=0.366, train_acc_epoch=0.840]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.76it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.64it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.57it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.55it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.54it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.65it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:15<00:00, 16.45it/s, train_loss_step=0.173, train_acc_step=1.000, val_loss=0.438, val_acc=0.787, val_auroc=0.868, train_loss_epoch=0.360, train_acc_epoch=0.842]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.77it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.59it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.55it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.52it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.52it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.64it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.102, train_acc_step=1.000, val_loss=0.439, val_acc=0.790, val_auroc=0.867, train_loss_epoch=0.357, train_acc_epoch=0.844]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.85it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.61it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.57it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.52it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.51it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.62it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:17<00:00, 16.33it/s, train_loss_step=0.112, train_acc_step=1.000, val_loss=0.436, val_acc=0.797, val_auroc=0.868, train_loss_epoch=0.356, train_acc_epoch=0.844]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.83it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.62it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.56it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.52it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.50it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.61it/s]
# Epoch 6: 100%|██████████| 4210/4210 [04:15<00:00, 16.46it/s, train_loss_step=0.0493, train_acc_step=1.000, val_loss=0.437, val_acc=0.781, val_auroc=0.867, train_loss_epoch=0.354, train_acc_epoch=0.846]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.82it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.64it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.59it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.55it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.52it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.63it/s]
# Epoch 7: 100%|██████████| 4210/4210 [04:17<00:00, 16.37it/s, train_loss_step=0.920, train_acc_step=0.600, val_loss=0.437, val_acc=0.790, val_auroc=0.868, train_loss_epoch=0.354, train_acc_epoch=0.846]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.85it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.64it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.59it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.55it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.52it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.60it/s]
# Epoch 7: 100%|██████████| 4210/4210 [04:20<00:00, 16.16it/s, train_loss_step=0.920, train_acc_step=0.600, val_loss=0.439, val_acc=0.794, val_auroc=0.869, train_loss_epoch=0.354, train_acc_epoch=0.846]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer0_mean/best-val_acc=0.797.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer0_mean/best-val_acc=0.797.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 16.92it/s]
# RESULT:{"layer": 0, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer0_mean/best-val_acc=0.797.ckpt"}
#   ✓ Layer 0 MEAN: acc=0.0000
#
# [Layer 1] MEAN pooling...
# 2025-12-02 22:11:41.625215: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764713501.646129    9823 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764713501.652701    9823 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764713501.668975    9823 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713501.669001    9823 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713501.669004    9823 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764713501.669006    9823 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 22:11:41.673697: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:17<00:00, 16.37it/s, train_loss_step=0.215, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:03, 13.47it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 14.79it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.33it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.58it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.74it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.92it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.317, train_acc_step=0.800, val_loss=0.433, val_acc=0.788, val_auroc=0.867, train_loss_epoch=0.400, train_acc_epoch=0.824]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.70it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.60it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.55it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.52it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.50it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.61it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:17<00:00, 16.33it/s, train_loss_step=0.392, train_acc_step=0.800, val_loss=0.434, val_acc=0.794, val_auroc=0.872, train_loss_epoch=0.363, train_acc_epoch=0.842]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.24it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.36it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.39it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.40it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.42it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.54it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:17<00:00, 16.37it/s, train_loss_step=0.162, train_acc_step=1.000, val_loss=0.425, val_acc=0.806, val_auroc=0.873, train_loss_epoch=0.358, train_acc_epoch=0.844]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.78it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.56it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.57it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.51it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.53it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.62it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:14<00:00, 16.56it/s, train_loss_step=0.214, train_acc_step=0.800, val_loss=0.430, val_acc=0.805, val_auroc=0.874, train_loss_epoch=0.355, train_acc_epoch=0.845]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.93it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.69it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.63it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.56it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.61it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.74it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:14<00:00, 16.55it/s, train_loss_step=0.141, train_acc_step=1.000, val_loss=0.428, val_acc=0.807, val_auroc=0.876, train_loss_epoch=0.354, train_acc_epoch=0.847]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.59it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.57it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.51it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.47it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.49it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.60it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:17<00:00, 16.34it/s, train_loss_step=0.141, train_acc_step=1.000, val_loss=0.429, val_acc=0.802, val_auroc=0.877, train_loss_epoch=0.352, train_acc_epoch=0.847]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer1_mean/best-val_acc=0.807.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer1_mean/best-val_acc=0.807.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 17.05it/s]
# RESULT:{"layer": 1, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer1_mean/best-val_acc=0.807.ckpt"}
#   ✓ Layer 1 MEAN: acc=0.0000
#
# [Layer 2] MEAN pooling...
# 2025-12-02 22:38:24.787927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764715104.807552   16737 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764715104.813451   16737 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764715104.828529   16737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764715104.828553   16737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764715104.828556   16737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764715104.828559   16737 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 22:38:24.833089: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:15<00:00, 16.50it/s, train_loss_step=0.149, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:03, 13.62it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 14.94it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.47it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.72it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.92it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.08it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:16<00:00, 16.40it/s, train_loss_step=0.356, train_acc_step=0.800, val_loss=0.420, val_acc=0.807, val_auroc=0.872, train_loss_epoch=0.380, train_acc_epoch=0.834]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 17.00it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.72it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.64it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.58it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.55it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.67it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:16<00:00, 16.40it/s, train_loss_step=0.379, train_acc_step=0.800, val_loss=0.424, val_acc=0.797, val_auroc=0.876, train_loss_epoch=0.349, train_acc_epoch=0.849]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 15.47it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.86it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.06it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.15it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.21it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.35it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:15<00:00, 16.45it/s, train_loss_step=0.0912, train_acc_step=1.000, val_loss=0.415, val_acc=0.807, val_auroc=0.880, train_loss_epoch=0.345, train_acc_epoch=0.852]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 15.63it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.57it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.50it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.54it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.53it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.71it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:16<00:00, 16.39it/s, train_loss_step=0.462, train_acc_step=0.800, val_loss=0.421, val_acc=0.805, val_auroc=0.876, train_loss_epoch=0.343, train_acc_epoch=0.852]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.89it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.49it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.12it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.98it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.90it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.00it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:16<00:00, 16.40it/s, train_loss_step=0.296, train_acc_step=1.000, val_loss=0.419, val_acc=0.808, val_auroc=0.881, train_loss_epoch=0.341, train_acc_epoch=0.854]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.82it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.56it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.57it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.52it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.51it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.61it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:20<00:00, 16.19it/s, train_loss_step=0.296, train_acc_step=1.000, val_loss=0.420, val_acc=0.805, val_auroc=0.880, train_loss_epoch=0.340, train_acc_epoch=0.855]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer2_mean/best-val_acc=0.808.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer2_mean/best-val_acc=0.808.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 16.96it/s]
# RESULT:{"layer": 2, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer2_mean/best-val_acc=0.808.ckpt"}
#   ✓ Layer 2 MEAN: acc=0.0000
#
# [Layer 3] MEAN pooling...
# 2025-12-02 23:05:00.351771: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764716700.371518   23606 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764716700.377519   23606 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764716700.392667   23606 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764716700.392692   23606 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764716700.392694   23606 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764716700.392697   23606 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 23:05:00.397441: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.153, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:03, 13.10it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 14.58it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.17it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.48it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.64it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.83it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:19<00:00, 16.20it/s, train_loss_step=0.204, train_acc_step=0.800, val_loss=0.381, val_acc=0.833, val_auroc=0.909, train_loss_epoch=0.350, train_acc_epoch=0.848]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.64it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.99it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.75it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.71it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.62it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.62it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:16<00:00, 16.38it/s, train_loss_step=0.411, train_acc_step=0.800, val_loss=0.383, val_acc=0.826, val_auroc=0.910, train_loss_epoch=0.320, train_acc_epoch=0.862]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.81it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.66it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.38it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.23it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.07it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.17it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:15<00:00, 16.49it/s, train_loss_step=0.115, train_acc_step=1.000, val_loss=0.371, val_acc=0.839, val_auroc=0.916, train_loss_epoch=0.315, train_acc_epoch=0.864]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.87it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.70it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.62it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.57it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.54it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.62it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:14<00:00, 16.55it/s, train_loss_step=0.803, train_acc_step=0.800, val_loss=0.378, val_acc=0.829, val_auroc=0.916, train_loss_epoch=0.312, train_acc_epoch=0.866]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.62it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.17it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.02it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.99it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.86it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.87it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:14<00:00, 16.53it/s, train_loss_step=0.250, train_acc_step=0.800, val_loss=0.376, val_acc=0.825, val_auroc=0.914, train_loss_epoch=0.311, train_acc_epoch=0.867]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 17.10it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.98it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.83it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.74it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.66it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.77it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:18<00:00, 16.32it/s, train_loss_step=0.250, train_acc_step=0.800, val_loss=0.376, val_acc=0.833, val_auroc=0.914, train_loss_epoch=0.309, train_acc_epoch=0.867]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer3_mean/best-val_acc=0.839.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer3_mean/best-val_acc=0.839.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 17.20it/s]
# RESULT:{"layer": 3, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer3_mean/best-val_acc=0.839.ckpt"}
#   ✓ Layer 3 MEAN: acc=0.0000
#
# [Layer 4] MEAN pooling...
# 2025-12-02 23:31:39.212455: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764718299.232321   30481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764718299.238327   30481 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764718299.253574   30481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764718299.253596   30481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764718299.253599   30481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764718299.253657   30481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 23:31:39.258203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:16<00:00, 16.43it/s, train_loss_step=0.163, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:03, 13.43it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 14.69it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.26it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.55it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.71it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.87it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:16<00:00, 16.43it/s, train_loss_step=0.259, train_acc_step=0.800, val_loss=0.367, val_acc=0.839, val_auroc=0.917, train_loss_epoch=0.340, train_acc_epoch=0.852]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.92it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.68it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.60it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.58it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.52it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.61it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:16<00:00, 16.44it/s, train_loss_step=0.347, train_acc_step=0.800, val_loss=0.370, val_acc=0.829, val_auroc=0.920, train_loss_epoch=0.316, train_acc_epoch=0.864]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.96it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.76it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.64it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.60it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.58it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.68it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:16<00:00, 16.43it/s, train_loss_step=0.0484, train_acc_step=1.000, val_loss=0.357, val_acc=0.847, val_auroc=0.924, train_loss_epoch=0.311, train_acc_epoch=0.867]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 15.45it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.68it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.52it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.69it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.86it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.04it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:15<00:00, 16.46it/s, train_loss_step=0.610, train_acc_step=0.800, val_loss=0.368, val_acc=0.830, val_auroc=0.922, train_loss_epoch=0.309, train_acc_epoch=0.867]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.85it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.68it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.45it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.25it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.12it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.19it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.192, train_acc_step=0.800, val_loss=0.362, val_acc=0.834, val_auroc=0.919, train_loss_epoch=0.306, train_acc_epoch=0.869]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.98it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.71it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.63it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.57it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.56it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.66it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:20<00:00, 16.17it/s, train_loss_step=0.192, train_acc_step=0.800, val_loss=0.365, val_acc=0.833, val_auroc=0.920, train_loss_epoch=0.305, train_acc_epoch=0.870]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer4_mean/best-val_acc=0.847.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer4_mean/best-val_acc=0.847.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 16.98it/s]
# RESULT:{"layer": 4, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer4_mean/best-val_acc=0.847.ckpt"}
#   ✓ Layer 4 MEAN: acc=0.0000
#
# [Layer 5] MEAN pooling...
# 2025-12-02 23:58:15.133753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764719895.154463   37350 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764719895.160749   37350 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764719895.176902   37350 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764719895.176925   37350 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764719895.176933   37350 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764719895.176937   37350 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-02 23:58:15.181903: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 67349
# [sst.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 872
# [sst.parquet] Labels - Unique: [-1], Range: [-1, -1], Count: 1821
#   → Test set with -1 labels (no ground truth) - will skip loss/metrics computation
# Epoch 0: 100%|██████████| 4210/4210 [04:18<00:00, 16.29it/s, train_loss_step=0.177, train_acc_step=1.000]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:03, 13.33it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 14.75it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.26it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.54it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.71it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 15.89it/s]
# Epoch 1: 100%|██████████| 4210/4210 [04:19<00:00, 16.24it/s, train_loss_step=0.283, train_acc_step=0.800, val_loss=0.374, val_acc=0.830, val_auroc=0.912, train_loss_epoch=0.350, train_acc_epoch=0.848]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 15.60it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.47it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.83it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.97it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.05it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.19it/s]
# Epoch 2: 100%|██████████| 4210/4210 [04:18<00:00, 16.26it/s, train_loss_step=0.318, train_acc_step=0.800, val_loss=0.378, val_acc=0.838, val_auroc=0.919, train_loss_epoch=0.325, train_acc_epoch=0.860]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.85it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.60it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.59it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.54it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.53it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.62it/s]
# Epoch 3: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.0693, train_acc_step=1.000, val_loss=0.362, val_acc=0.844, val_auroc=0.924, train_loss_epoch=0.319, train_acc_epoch=0.863]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.87it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.67it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.60it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.54it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.55it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.66it/s]
# Epoch 4: 100%|██████████| 4210/4210 [04:17<00:00, 16.38it/s, train_loss_step=0.626, train_acc_step=0.800, val_loss=0.369, val_acc=0.841, val_auroc=0.925, train_loss_epoch=0.317, train_acc_epoch=0.863]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.63it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 16.59it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 16.54it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 16.51it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 16.47it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.61it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:17<00:00, 16.36it/s, train_loss_step=0.210, train_acc_step=0.800, val_loss=0.363, val_acc=0.830, val_auroc=0.922, train_loss_epoch=0.315, train_acc_epoch=0.865]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/55 [00:00<?, ?it/s]
# Validation DataLoader 0:  18%|█▊        | 10/55 [00:00<00:02, 16.04it/s]
# Validation DataLoader 0:  36%|███▋      | 20/55 [00:01<00:02, 15.61it/s]
# Validation DataLoader 0:  55%|█████▍    | 30/55 [00:01<00:01, 15.57it/s]
# Validation DataLoader 0:  73%|███████▎  | 40/55 [00:02<00:00, 15.80it/s]
# Validation DataLoader 0:  91%|█████████ | 50/55 [00:03<00:00, 15.91it/s]
# Validation DataLoader 0: 100%|██████████| 55/55 [00:03<00:00, 16.08it/s]
# Epoch 5: 100%|██████████| 4210/4210 [04:20<00:00, 16.14it/s, train_loss_step=0.210, train_acc_step=0.800, val_loss=0.367, val_acc=0.831, val_auroc=0.922, train_loss_epoch=0.313, train_acc_epoch=0.865]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer5_mean/best-val_acc=0.844.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer5_mean/best-val_acc=0.844.ckpt
#
# Testing DataLoader 0: 100%|██████████| 114/114 [00:06<00:00, 17.37it/s]
# RESULT:{"layer": 5, "pooling": "mean", "test_acc": 0, "test_auroc": 0, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_mean/checkpoints/layer5_mean/best-val_acc=0.844.ckpt"}
#   ✓ Layer 5 MEAN: acc=0.0000
#
# ========================================
# MEAN Sweep Complete!
# ========================================
# Results: /content/drive/MyDrive/NOT_results/sweep_mean/results_mean.json
# Best: Layer 0 -> AUROC 0.0000

# %% [markdown]
# ## 4. Check Results

# %%
import json
import os

results_file = os.path.join(os.environ['DRIVE_OUTPUT'], 'sweep_mean', 'results_mean.json')

if os.path.exists(results_file):
    with open(results_file, 'r') as f:
        results = json.load(f)

    print(f"MEAN Sweep Results ({len(results)} experiments)")
    print("=" * 50)

    for r in sorted(results, key=lambda x: x.get('test_auroc', 0), reverse=True):
        print(f"Layer {r['layer']}: AUROC={r.get('test_auroc', 0):.4f}, Acc={r.get('test_acc', 0):.4f}")

    best = max(results, key=lambda x: x.get('test_auroc', 0))
    print(f"\nBest: Layer {best['layer']} with AUROC {best.get('test_auroc', 0):.4f}")
else:
    print(f"Results not found at {results_file}")
# Out:
# MEAN Sweep Results (6 experiments)
# ==================================================
# Layer 0: AUROC=0.0000, Acc=0.0000
# Layer 1: AUROC=0.0000, Acc=0.0000
# Layer 2: AUROC=0.0000, Acc=0.0000
# Layer 3: AUROC=0.0000, Acc=0.0000
# Layer 4: AUROC=0.0000, Acc=0.0000
# Layer 5: AUROC=0.0000, Acc=0.0000
#
# Best: Layer 0 with AUROC 0.0000
