# %% [markdown]
# # Sweep: TOKEN Pooling - Negation Detection
#
# Train probes to detect **negation** (NOT sentiment!) across all layers using TOKEN pooling (around "not" token).
#
# **Task**: Binary classification
# - Label 0: No negation (e.g., "good", "the movie is great")
# - Label 1: Has negation (e.g., "not good", "the movie is not great")
#
# **Goal**: Find which layer is best at detecting negation. Expected: Layer 3 (based on cosine similarity findings).
#
# Run this notebook in **Colab 3** while running `07_sweep_cls_negation_detection.ipynb` and `07_sweep_mean_negation_detection.ipynb` in separate Colab runtimes.
#
# All results are saved to Google Drive so they can be merged later.

# %% [markdown]
# ## 1. Setup

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone or pull the repository
# !git clone https://github.com/TheMattWang/Negation-Origin-Tracing.git 2>/dev/null || (cd Negation-Origin-Tracing && git pull)
# %cd Negation-Origin-Tracing
# Out:
# /content/Negation-Origin-Tracing

# %%
# Install dependencies
# %pip install -q torch lightning transformers datasets pandas pyarrow matplotlib seaborn scikit-learn tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 846.0/846.0 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 53.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 56.4 MB/s eta 0:00:00

# %%
# Set shared output location on Google Drive
import os
os.environ['DRIVE_OUTPUT'] = '/content/drive/MyDrive/NOT_results'

# Create the directory
# !mkdir -p /content/drive/MyDrive/NOT_results

print(f"Results will be saved to: {os.environ['DRIVE_OUTPUT']}")
# Out:
# Results will be saved to: /content/drive/MyDrive/NOT_results

# %%
# Check GPU
import torch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# GPU available: True
# GPU: Tesla T4

# %% [markdown]
# ## 2. Prepare Negation Detection Dataset
#
# Download JinaAI negation dataset and convert to detection format:
# - Anchor/Entailment sentences → Label 0 (no negation)
# - Negative sentences → Label 1 (has negation)

# %%
# Check if negation detection dataset already exists
import os

train_path = 'data/raw/train/negation_detection.parquet'
val_path = 'data/raw/validation/negation_detection.parquet'
test_path = 'data/raw/test/negation_detection.parquet'

if os.path.exists(train_path) and os.path.exists(val_path) and os.path.exists(test_path):
    print("Negation detection dataset already exists!")

    # Show stats
    import pandas as pd
    for name, path in [('Train', train_path), ('Validation', val_path), ('Test', test_path)]:
        df = pd.read_parquet(path)
        print(f"  {name}: {len(df)} samples, labels: {sorted(df['label'].unique())}")
else:
    print("Preparing negation detection dataset...")
    # !python src/data/prepare_negation_detection.py
# Out:
# Preparing negation detection dataset...
# ============================================================
# Preparing Negation Detection Dataset
# ============================================================
# Downloading jinaai/negation-dataset-v2 (50k train, 1k test)...
# README.md: 3.75kB [00:00, 7.30MB/s]
# negation-dataset-v2.py: 4.54kB [00:00, 18.4MB/s]
# Error downloading dataset: Dataset scripts are no longer supported, but found negation-dataset-v2.py
# Trying fallback: jinaai/negation-dataset...
# README.md: 3.99kB [00:00, 19.3MB/s]
# negation_training.tsv: 1.39MB [00:00, 50.1MB/s]
# negation_evaluation.tsv: 73.7kB [00:00, 123MB/s]
# Generating train split: 100% 10000/10000 [00:00<00:00, 239643.02 examples/s]
# Generating test split: 100% 500/500 [00:00<00:00, 92897.10 examples/s]
#   Cached train: 10000 examples -> /content/Negation-Origin-Tracing/data/raw/negation/train.parquet
#   Cached test: 500 examples -> /content/Negation-Origin-Tracing/data/raw/negation/test.parquet
#
# Converting triplets to negation detection format...
#
#   Processing train split (10000 triplets)...
#     -> 27268 detection examples
#
#   Processing test split (500 triplets)...
#     -> 1458 detection examples
#
#   Creating validation split from train data...
#     Train: 24542, Validation: 2726
#
# Saving processed datasets...
#   Saved train: 24542 examples -> /content/Negation-Origin-Tracing/data/raw/train/negation_detection.parquet
#   Saved validation: 2726 examples -> /content/Negation-Origin-Tracing/data/raw/validation/negation_detection.parquet
#   Saved test: 1458 examples -> /content/Negation-Origin-Tracing/data/raw/test/negation_detection.parquet
#
# Validating labels...
#   train:
#     Samples: 24542
#     Unique labels: [np.int64(0), np.int64(1)]
#     Distribution: {0: 16014, 1: 8528}
#     Balance ratio: 0.53
#   validation:
#     Samples: 2726
#     Unique labels: [np.int64(0), np.int64(1)]
#     Distribution: {0: 1714, 1: 1012}
#     Balance ratio: 0.59
#   test:
#     Samples: 1458
#     Unique labels: [np.int64(0), np.int64(1)]
#     Distribution: {0: 959, 1: 499}
#     Balance ratio: 0.52
#
# ✓ All datasets have valid labels!
#
# ============================================================
# Summary
# ============================================================
#
# Output directory: /content/Negation-Origin-Tracing/data/raw
#
# Files created:
#   /content/Negation-Origin-Tracing/data/raw/train/negation_detection.parquet
#     24542 examples, labels: [np.int64(0), np.int64(1)]
#   /content/Negation-Origin-Tracing/data/raw/validation/negation_detection.parquet
#     2726 examples, labels: [np.int64(0), np.int64(1)]
#   /content/Negation-Origin-Tracing/data/raw/test/negation_detection.parquet
#     1458 examples, labels: [np.int64(0), np.int64(1)]
#
# Dataset format:
#   - 'sentence': Text to classify
#   - 'label': 0 = no negation, 1 = has negation
#
# ✓ Preparation complete!

# %% [markdown]
# ## 3. Run TOKEN Pooling Sweep - Negation Detection
#
# This trains probes on all 6 layers using TOKEN pooling (around "not" token) to detect negation.

# %%
# Run the TOKEN negation detection sweep
# !chmod +x run_sweep_token_negation_detection.sh
# !./run_sweep_token_negation_detection.sh
# Out:
# Saving to Google Drive: /content/drive/MyDrive/NOT_results/sweep_token_negation_detection
# ========================================
# Layer Sweep: TOKEN Pooling - NEGATION DETECTION
# ========================================
# Task: Binary classification (0=no negation, 1=has negation)
# Pooling: Around 'not' token position
# Layers: 0-5
# Output: /content/drive/MyDrive/NOT_results/sweep_token_negation_detection
#
#
# [Layer 0] TOKEN pooling - Negation Detection...
# 2025-12-03 18:27:40.083054: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764786460.104210    1401 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764786460.110252    1401 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764786460.125348    1401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764786460.125365    1401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764786460.125367    1401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764786460.125368    1401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-03 18:27:40.130008: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 24542
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 2726
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 1458
# Epoch 0: 100%|██████████| 1534/1534 [01:36<00:00, 15.93it/s, train_loss_step=0.243, train_acc_step=0.929]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:01<00:17,  9.22it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:12, 11.65it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:11, 12.74it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:09, 13.42it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 13.86it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.17it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:07, 14.43it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 14.61it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:06<00:05, 14.72it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 14.68it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:04, 14.63it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:08<00:03, 14.64it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 14.63it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 14.57it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:10<00:01, 14.65it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 14.73it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:11<00:00, 14.80it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:11<00:00, 14.85it/s]
# Epoch 1: 100%|██████████| 1534/1534 [01:36<00:00, 15.90it/s, train_loss_step=0.095, train_acc_step=1.000, val_loss=0.319, val_acc=0.866, val_auroc=0.919, train_loss_epoch=0.342, train_acc_epoch=0.866]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 14.85it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.80it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:09, 14.85it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 14.83it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 14.75it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.90it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.09it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.19it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.27it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.37it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.45it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.49it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.53it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.57it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.61it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.62it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.64it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.68it/s]
# Epoch 2: 100%|██████████| 1534/1534 [01:36<00:00, 15.86it/s, train_loss_step=0.150, train_acc_step=0.929, val_loss=0.304, val_acc=0.872, val_auroc=0.925, train_loss_epoch=0.314, train_acc_epoch=0.871]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.37it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.34it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.26it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.20it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.22it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.18it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.18it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.12it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.08it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.02it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.91it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.79it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.73it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.63it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.57it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.61it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.66it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.71it/s]
# Epoch 3: 100%|██████████| 1534/1534 [01:36<00:00, 15.94it/s, train_loss_step=0.438, train_acc_step=0.857, val_loss=0.301, val_acc=0.871, val_auroc=0.931, train_loss_epoch=0.302, train_acc_epoch=0.875]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.19it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.19it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.07it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.11it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.07it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.04it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.95it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.98it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.80it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.67it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.57it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.49it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.41it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.45it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.49it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.52it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.58it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.63it/s]
# Epoch 4: 100%|██████████| 1534/1534 [01:36<00:00, 15.88it/s, train_loss_step=0.566, train_acc_step=0.643, val_loss=0.290, val_acc=0.877, val_auroc=0.934, train_loss_epoch=0.294, train_acc_epoch=0.877]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.52it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.22it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.23it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.21it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.25it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.27it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.30it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.24it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.20it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.14it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.16it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.15it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.16it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 16.18it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 16.16it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:09<00:00, 16.09it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 16.01it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 16.05it/s]
# Epoch 5: 100%|██████████| 1534/1534 [01:36<00:00, 15.92it/s, train_loss_step=0.192, train_acc_step=1.000, val_loss=0.287, val_acc=0.883, val_auroc=0.935, train_loss_epoch=0.288, train_acc_epoch=0.879]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.44it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.26it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.25it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.20it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.22it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.23it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.21it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.23it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.19it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.12it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.01it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.86it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.79it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.73it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.67it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.72it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.76it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.81it/s]
# Epoch 6: 100%|██████████| 1534/1534 [01:35<00:00, 15.99it/s, train_loss_step=0.374, train_acc_step=0.857, val_loss=0.282, val_acc=0.879, val_auroc=0.937, train_loss_epoch=0.284, train_acc_epoch=0.881]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.38it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.29it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.25it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.17it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.15it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.19it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.21it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.21it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.07it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.95it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.86it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.78it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.63it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.58it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.61it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.64it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.68it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.72it/s]
# Epoch 7: 100%|██████████| 1534/1534 [01:35<00:00, 16.02it/s, train_loss_step=0.232, train_acc_step=0.929, val_loss=0.290, val_acc=0.875, val_auroc=0.938, train_loss_epoch=0.278, train_acc_epoch=0.883]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 15.95it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.10it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.11it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.17it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.18it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.13it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.96it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.82it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.72it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.64it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.47it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.45it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.52it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.57it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.60it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.64it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.65it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.69it/s]
# Epoch 8: 100%|██████████| 1534/1534 [01:35<00:00, 16.01it/s, train_loss_step=0.364, train_acc_step=0.857, val_loss=0.282, val_acc=0.878, val_auroc=0.939, train_loss_epoch=0.275, train_acc_epoch=0.886]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.26it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.16it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.01it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.03it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.83it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.64it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.51it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.44it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.36it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.33it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.38it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.44it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.47it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:01, 15.53it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.56it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.60it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.63it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.68it/s]
# Epoch 9: 100%|██████████| 1534/1534 [01:36<00:00, 15.88it/s, train_loss_step=0.208, train_acc_step=1.000, val_loss=0.272, val_acc=0.888, val_auroc=0.941, train_loss_epoch=0.271, train_acc_epoch=0.888]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 14.85it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.56it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:09, 14.98it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.25it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.47it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.56it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.61it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.65it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.72it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.79it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.81it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.86it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.87it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.90it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.92it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.93it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.94it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.99it/s]
# Epoch 9: 100%|██████████| 1534/1534 [01:47<00:00, 14.29it/s, train_loss_step=0.208, train_acc_step=1.000, val_loss=0.273, val_acc=0.896, val_auroc=0.943, train_loss_epoch=0.269, train_acc_epoch=0.889]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 1534/1534 [01:54<00:00, 13.38it/s, train_loss_step=0.208, train_acc_step=1.000, val_loss=0.273, val_acc=0.896, val_auroc=0.943, train_loss_epoch=0.269, train_acc_epoch=0.889]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer0_token/best-val_acc=0.896.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer0_token/best-val_acc=0.896.ckpt
#
# Testing DataLoader 0: 100%|██████████| 92/92 [00:05<00:00, 16.23it/s]
# RESULT:{"layer": 0, "pooling": "token", "task": "negation_detection", "test_acc": 0.8209876418113708, "test_auroc": 0.8875449299812317, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer0_token/best-val_acc=0.896.ckpt", "note": "test_set_evaluation"}
#   ✓ Layer 0 TOKEN: acc=0.8210, auroc=0.8875
#
# [Layer 1] TOKEN pooling - Negation Detection...
# 2025-12-03 18:46:32.690802: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764787592.711227    6191 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764787592.717378    6191 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764787592.732614    6191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764787592.732637    6191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764787592.732640    6191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764787592.732642    6191 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-03 18:46:32.737624: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 24542
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 2726
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 1458
# Epoch 0: 100%|██████████| 1534/1534 [01:37<00:00, 15.78it/s, train_loss_step=0.204, train_acc_step=0.929]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:14, 11.21it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:11, 12.70it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:10, 13.21it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:09, 13.80it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 14.23it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.45it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 14.67it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 14.80it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:06<00:05, 14.89it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.00it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:04, 15.08it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.18it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.24it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.28it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.34it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.39it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:11<00:00, 15.43it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:11<00:00, 15.48it/s]
# Epoch 1: 100%|██████████| 1534/1534 [01:37<00:00, 15.81it/s, train_loss_step=0.0888, train_acc_step=1.000, val_loss=0.296, val_acc=0.877, val_auroc=0.937, train_loss_epoch=0.326, train_acc_epoch=0.870]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.15it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.01it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.09it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.77it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.52it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.40it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.29it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 15.14it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.20it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.26it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.32it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.37it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.41it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.43it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.47it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.49it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.53it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.57it/s]
# Epoch 2: 100%|██████████| 1534/1534 [01:37<00:00, 15.79it/s, train_loss_step=0.132, train_acc_step=0.929, val_loss=0.272, val_acc=0.886, val_auroc=0.943, train_loss_epoch=0.289, train_acc_epoch=0.881]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.20it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.10it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.02it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.95it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.94it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 15.95it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.98it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.93it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.95it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.97it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.96it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.93it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.85it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.76it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.68it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.61it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.52it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.56it/s]
# Epoch 3: 100%|██████████| 1534/1534 [01:37<00:00, 15.79it/s, train_loss_step=0.436, train_acc_step=0.857, val_loss=0.263, val_acc=0.892, val_auroc=0.947, train_loss_epoch=0.273, train_acc_epoch=0.891]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 15.21it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 15.61it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 15.80it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.83it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.89it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 15.97it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.00it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.01it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.00it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.00it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.02it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.02it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.01it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 16.03it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 16.03it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:09<00:00, 16.04it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 16.00it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 16.04it/s]
# Epoch 4: 100%|██████████| 1534/1534 [01:36<00:00, 15.86it/s, train_loss_step=0.500, train_acc_step=0.643, val_loss=0.257, val_acc=0.895, val_auroc=0.950, train_loss_epoch=0.265, train_acc_epoch=0.895]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.50it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.39it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.26it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.89it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.66it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.48it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.40it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.22it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.21it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.29it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.38it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.42it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.47it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:01, 15.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.53it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.57it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.60it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.65it/s]
# Epoch 5: 100%|██████████| 1534/1534 [01:36<00:00, 15.84it/s, train_loss_step=0.0619, train_acc_step=1.000, val_loss=0.260, val_acc=0.898, val_auroc=0.952, train_loss_epoch=0.258, train_acc_epoch=0.899]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.56it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.25it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.21it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.20it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.16it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.11it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.12it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.87it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.73it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.61it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.54it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.42it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.42it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.49it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.54it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.57it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.62it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.66it/s]
# Epoch 6: 100%|██████████| 1534/1534 [01:36<00:00, 15.97it/s, train_loss_step=0.303, train_acc_step=0.857, val_loss=0.265, val_acc=0.892, val_auroc=0.955, train_loss_epoch=0.253, train_acc_epoch=0.902]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.26it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.09it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.13it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.05it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.09it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.85it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.66it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.57it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.48it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.35it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.42it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.46it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.53it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.56it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.59it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.63it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.65it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.70it/s]
# Epoch 6: 100%|██████████| 1534/1534 [01:46<00:00, 14.34it/s, train_loss_step=0.303, train_acc_step=0.857, val_loss=0.279, val_acc=0.889, val_auroc=0.956, train_loss_epoch=0.248, train_acc_epoch=0.902]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer1_token/best-val_acc=0.898.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer1_token/best-val_acc=0.898.ckpt
#
# Testing DataLoader 0: 100%|██████████| 92/92 [00:05<00:00, 16.24it/s]
# RESULT:{"layer": 1, "pooling": "token", "task": "negation_detection", "test_acc": 0.8484224677085876, "test_auroc": 0.9009188413619995, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer1_token/best-val_acc=0.898.ckpt", "note": "test_set_evaluation"}
#   ✓ Layer 1 TOKEN: acc=0.8484, auroc=0.9009
#
# [Layer 2] TOKEN pooling - Negation Detection...
# 2025-12-03 19:00:07.966912: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764788407.999300    9602 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764788408.009166    9602 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764788408.033754    9602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764788408.033786    9602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764788408.033789    9602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764788408.033791    9602 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-03 19:00:08.040611: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 24542
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 2726
# [negation_detection.parquet] Labels - Unique: [0, 1], Range: [0, 1], Count: 1458
# Epoch 0: 100%|██████████| 1534/1534 [01:36<00:00, 15.84it/s, train_loss_step=0.225, train_acc_step=0.929]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:12, 13.17it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.08it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:09, 14.39it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:09, 14.42it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 14.57it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.52it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 14.66it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 14.85it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.01it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.15it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:04, 15.22it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.31it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.39it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.45it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.50it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.55it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.59it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.64it/s]
# Epoch 1: 100%|██████████| 1534/1534 [01:36<00:00, 15.87it/s, train_loss_step=0.0593, train_acc_step=1.000, val_loss=0.264, val_acc=0.895, val_auroc=0.948, train_loss_epoch=0.291, train_acc_epoch=0.881]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.48it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.18it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.14it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.16it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.13it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.15it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.11it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.99it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.87it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.72it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.65it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.54it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.52it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:01, 15.54it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.57it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.59it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.62it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.66it/s]
# Epoch 2: 100%|██████████| 1534/1534 [01:36<00:00, 15.84it/s, train_loss_step=0.0922, train_acc_step=1.000, val_loss=0.241, val_acc=0.906, val_auroc=0.955, train_loss_epoch=0.248, train_acc_epoch=0.906]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.18it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.05it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 15.96it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.99it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.99it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.02it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.00it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.01it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.01it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.00it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.02it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.03it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.04it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 16.05it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 16.04it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.95it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.85it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.89it/s]
# Epoch 3: 100%|██████████| 1534/1534 [01:37<00:00, 15.81it/s, train_loss_step=0.452, train_acc_step=0.857, val_loss=0.230, val_acc=0.911, val_auroc=0.959, train_loss_epoch=0.233, train_acc_epoch=0.913]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 14.64it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.65it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:09, 14.58it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:09, 14.53it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 14.54it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.78it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 14.95it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 15.10it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.18it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.26it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.31it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.38it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.43it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:02, 15.47it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.49it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.53it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.56it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.61it/s]
# Epoch 4: 100%|██████████| 1534/1534 [01:36<00:00, 15.90it/s, train_loss_step=0.332, train_acc_step=0.857, val_loss=0.227, val_acc=0.911, val_auroc=0.962, train_loss_epoch=0.225, train_acc_epoch=0.916]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 14.78it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.60it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:09, 15.03it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.27it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.41it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.47it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.51it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.55it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.62it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.65it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.68it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.71it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.73it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.75it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.78it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.79it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.81it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.85it/s]
# Epoch 5: 100%|██████████| 1534/1534 [01:36<00:00, 15.87it/s, train_loss_step=0.0365, train_acc_step=1.000, val_loss=0.225, val_acc=0.913, val_auroc=0.963, train_loss_epoch=0.219, train_acc_epoch=0.918]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.24it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.11it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.09it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.11it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.09it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.07it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.05it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.09it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.08it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.02it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.91it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.78it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.70it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.60it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.55it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.59it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.62it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.66it/s]
# Epoch 6: 100%|██████████| 1534/1534 [01:35<00:00, 15.99it/s, train_loss_step=0.187, train_acc_step=0.929, val_loss=0.241, val_acc=0.906, val_auroc=0.964, train_loss_epoch=0.216, train_acc_epoch=0.919]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ...
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.67it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.70it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.74it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.78it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.80it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.84it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.85it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.90it/s]
# Epoch 2: 100%|██████████| 1534/1534 [01:36<00:00, 15.88it/s, train_loss_step=0.0668, train_acc_step=1.000, val_loss=0.200, val_acc=0.923, val_auroc=0.965, train_loss_epoch=0.200, train_acc_epoch=0.929]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.53it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.42it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.35it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.30it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.25it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.25it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.22it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.24it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:04, 16.24it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.21it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.20it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.20it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.11it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 16.04it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.93it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.87it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.79it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.82it/s]
# Epoch 3: 100%|██████████| 1534/1534 [01:36<00:00, 15.86it/s, train_loss_step=0.400, train_acc_step=0.857, val_loss=0.195, val_acc=0.926, val_auroc=0.967, train_loss_epoch=0.189, train_acc_epoch=0.931]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 14.87it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.93it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:02<00:09, 14.68it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 14.88it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 15.11it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.30it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.47it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.56it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.62it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.65it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.69it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.73it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.77it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.79it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.80it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.82it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.85it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.90it/s]
# Epoch 4: 100%|██████████| 1534/1534 [01:36<00:00, 15.86it/s, train_loss_step=0.328, train_acc_step=0.857, val_loss=0.192, val_acc=0.926, val_auroc=0.969, train_loss_epoch=0.184, train_acc_epoch=0.934]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.42it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.18it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.21it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.17it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.21it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.16it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.11it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.16it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.14it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 16.15it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.14it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.09it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.01it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.90it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.85it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.75it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.73it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.77it/s]
# Epoch 5: 100%|██████████| 1534/1534 [01:35<00:00, 16.00it/s, train_loss_step=0.0377, train_acc_step=1.000, val_loss=0.205, val_acc=0.924, val_auroc=0.968, train_loss_epoch=0.180, train_acc_epoch=0.935]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.34it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.20it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.21it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.20it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.16it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.16it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.13it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.19it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.06it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.93it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.83it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.75it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.64it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.66it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.71it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.71it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.73it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.78it/s]
# Epoch 6: 100%|██████████| 1534/1534 [01:36<00:00, 15.85it/s, train_loss_step=0.138, train_acc_step=0.929, val_loss=0.186, val_acc=0.931, val_auroc=0.969, train_loss_epoch=0.177, train_acc_epoch=0.936]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 16.04it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 15.30it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:09, 15.04it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 14.95it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:08, 14.93it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:04<00:07, 14.84it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 14.98it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:06, 15.13it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.22it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.32it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.35it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.43it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.47it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:09<00:01, 15.50it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.54it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.56it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.60it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.65it/s]
# Epoch 7: 100%|██████████| 1534/1534 [01:36<00:00, 15.85it/s, train_loss_step=0.252, train_acc_step=0.929, val_loss=0.188, val_acc=0.930, val_auroc=0.969, train_loss_epoch=0.175, train_acc_epoch=0.937]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:10, 15.13it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:10, 14.62it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:09, 15.07it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 15.33it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 15.47it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:07, 15.56it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.65it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.69it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.72it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.78it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 15.80it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.84it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.84it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.87it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.89it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.92it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.95it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 16.00it/s]
# Epoch 8: 100%|██████████| 1534/1534 [01:36<00:00, 15.91it/s, train_loss_step=0.474, train_acc_step=0.929, val_loss=0.197, val_acc=0.928, val_auroc=0.970, train_loss_epoch=0.173, train_acc_epoch=0.939]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.20it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.00it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.05it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.04it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.04it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.02it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 16.01it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:04<00:05, 16.04it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 16.01it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.99it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:06<00:03, 16.01it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 16.01it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 16.01it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 16.00it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.93it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.85it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.76it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.81it/s]
# Epoch 9: 100%|██████████| 1534/1534 [01:37<00:00, 15.80it/s, train_loss_step=0.330, train_acc_step=0.857, val_loss=0.184, val_acc=0.934, val_auroc=0.970, train_loss_epoch=0.171, train_acc_epoch=0.939]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/171 [00:00<?, ?it/s]
# Validation DataLoader 0:   6%|▌         | 10/171 [00:00<00:09, 16.52it/s]
# Validation DataLoader 0:  12%|█▏        | 20/171 [00:01<00:09, 16.24it/s]
# Validation DataLoader 0:  18%|█▊        | 30/171 [00:01<00:08, 16.22it/s]
# Validation DataLoader 0:  23%|██▎       | 40/171 [00:02<00:08, 16.19it/s]
# Validation DataLoader 0:  29%|██▉       | 50/171 [00:03<00:07, 16.15it/s]
# Validation DataLoader 0:  35%|███▌      | 60/171 [00:03<00:06, 16.15it/s]
# Validation DataLoader 0:  41%|████      | 70/171 [00:04<00:06, 15.88it/s]
# Validation DataLoader 0:  47%|████▋     | 80/171 [00:05<00:05, 15.73it/s]
# Validation DataLoader 0:  53%|█████▎    | 90/171 [00:05<00:05, 15.65it/s]
# Validation DataLoader 0:  58%|█████▊    | 100/171 [00:06<00:04, 15.53it/s]
# Validation DataLoader 0:  64%|██████▍   | 110/171 [00:07<00:03, 15.42it/s]
# Validation DataLoader 0:  70%|███████   | 120/171 [00:07<00:03, 15.51it/s]
# Validation DataLoader 0:  76%|███████▌  | 130/171 [00:08<00:02, 15.57it/s]
# Validation DataLoader 0:  82%|████████▏ | 140/171 [00:08<00:01, 15.62it/s]
# Validation DataLoader 0:  88%|████████▊ | 150/171 [00:09<00:01, 15.65it/s]
# Validation DataLoader 0:  94%|█████████▎| 160/171 [00:10<00:00, 15.66it/s]
# Validation DataLoader 0:  99%|█████████▉| 170/171 [00:10<00:00, 15.69it/s]
# Validation DataLoader 0: 100%|██████████| 171/171 [00:10<00:00, 15.73it/s]
# Epoch 9: 100%|██████████| 1534/1534 [01:47<00:00, 14.21it/s, train_loss_step=0.330, train_acc_step=0.857, val_loss=0.184, val_acc=0.933, val_auroc=0.972, train_loss_epoch=0.169, train_acc_epoch=0.940]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 1534/1534 [01:47<00:00, 14.21it/s, train_loss_step=0.330, train_acc_step=0.857, val_loss=0.184, val_acc=0.933, val_auroc=0.972, train_loss_epoch=0.169, train_acc_epoch=0.940]Restoring states from the checkpoint path at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer5_token/best-val_acc=0.934.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer5_token/best-val_acc=0.934.ckpt
#
# Testing DataLoader 0: 100%|██████████| 92/92 [00:05<00:00, 16.53it/s]
# RESULT:{"layer": 5, "pooling": "token", "task": "negation_detection", "test_acc": 0.8923182487487793, "test_auroc": 0.943803608417511, "checkpoint": "/content/drive/MyDrive/NOT_results/sweep_token_negation_detection/checkpoints/layer5_token/best-val_acc=0.934.ckpt", "note": "test_set_evaluation"}
#   ✓ Layer 5 TOKEN: acc=0.8923, auroc=0.9438
#
# ========================================
# TOKEN Negation Detection Sweep Complete!
# ========================================
# Results: /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/results_token_negation_detection.json
# Best: Layer 5 -> AUROC 0.9438, Acc 0.8923
#
# All layers (sorted by AUROC):
#   Layer 5: AUROC=0.9438, Acc=0.8923
#   Layer 4: AUROC=0.9417, Acc=0.8971
#   Layer 3: AUROC=0.9374, Acc=0.8909
#   Layer 2: AUROC=0.9301, Acc=0.8841
#   Layer 1: AUROC=0.9009, Acc=0.8484
#   Layer 0: AUROC=0.8875, Acc=0.8210

# %% [markdown]
# ## 4. Check Results

# %%
import json
import os

results_file = os.path.join(os.environ['DRIVE_OUTPUT'], 'sweep_token_negation_detection', 'results_token_negation_detection.json')

if os.path.exists(results_file):
    with open(results_file, 'r') as f:
        results = json.load(f)

    print(f"TOKEN Negation Detection Sweep Results ({len(results)} experiments)")
    print("=" * 60)
    print("\nTask: Negation Detection (0=no negation, 1=has negation)")
    print("\nResults by layer (sorted by AUROC):")

    for r in sorted(results, key=lambda x: x.get('test_auroc', 0), reverse=True):
        print(f"  Layer {r['layer']}: AUROC={r.get('test_auroc', 0):.4f}, Acc={r.get('test_acc', 0):.4f}")

    best = max(results, key=lambda x: x.get('test_auroc', 0))
    print(f"\n🏆 Best: Layer {best['layer']} with AUROC {best.get('test_auroc', 0):.4f}")

    # Check if Layer 3 is best (expected based on cosine similarity)
    if best['layer'] == 3:
        print("\n✅ Layer 3 is best for negation detection!")
        print("   This connects with the cosine similarity findings.")
    else:
        print(f"\n⚠️ Layer {best['layer']} is best (not Layer 3)")
        print("   This may suggest a different pattern than cosine similarity.")
else:
    print(f"Results not found at {results_file}")
# Out:
# TOKEN Negation Detection Sweep Results (6 experiments)
# ============================================================
#
# Task: Negation Detection (0=no negation, 1=has negation)
#
# Results by layer (sorted by AUROC):
#   Layer 5: AUROC=0.9438, Acc=0.8923
#   Layer 4: AUROC=0.9417, Acc=0.8971
#   Layer 3: AUROC=0.9374, Acc=0.8909
#   Layer 2: AUROC=0.9301, Acc=0.8841
#   Layer 1: AUROC=0.9009, Acc=0.8484
#   Layer 0: AUROC=0.8875, Acc=0.8210
#
# 🏆 Best: Layer 5 with AUROC 0.9438
#
# ⚠️ Layer 5 is best (not Layer 3)
#    This may suggest a different pattern than cosine similarity.

# %%
# Visualize results
import matplotlib.pyplot as plt
import json
import os

results_file = os.path.join(os.environ['DRIVE_OUTPUT'], 'sweep_token_negation_detection', 'results_token_negation_detection.json')

if os.path.exists(results_file):
    with open(results_file, 'r') as f:
        results = json.load(f)

    # Sort by layer
    results = sorted(results, key=lambda x: x['layer'])

    layers = [r['layer'] for r in results]
    aurocs = [r.get('test_auroc', 0) for r in results]
    accs = [r.get('test_acc', 0) for r in results]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    # AUROC plot
    bars1 = ax1.bar(layers, aurocs, color='steelblue', alpha=0.8)
    ax1.set_xlabel('Layer')
    ax1.set_ylabel('Test AUROC')
    ax1.set_title('Negation Detection: TOKEN Pooling - AUROC by Layer')
    ax1.set_xticks(layers)
    ax1.axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='Random baseline')
    ax1.legend()

    # Highlight best layer
    best_idx = aurocs.index(max(aurocs))
    bars1[best_idx].set_color('green')

    # Accuracy plot
    bars2 = ax2.bar(layers, accs, color='coral', alpha=0.8)
    ax2.set_xlabel('Layer')
    ax2.set_ylabel('Test Accuracy')
    ax2.set_title('Negation Detection: TOKEN Pooling - Accuracy by Layer')
    ax2.set_xticks(layers)
    ax2.axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='Random baseline')
    ax2.legend()

    # Highlight best layer
    best_idx = accs.index(max(accs))
    bars2[best_idx].set_color('green')

    plt.tight_layout()

    # Save figure
    fig_path = os.path.join(os.environ['DRIVE_OUTPUT'], 'sweep_token_negation_detection', 'token_negation_detection_results.png')
    plt.savefig(fig_path, dpi=150, bbox_inches='tight')
    print(f"Figure saved to: {fig_path}")

    plt.show()
else:
    print("No results to visualize")
# Out:
# Figure saved to: /content/drive/MyDrive/NOT_results/sweep_token_negation_detection/token_negation_detection_results.png
